# %% [markdown]
# # Model-Based RL
# In this exercise you will implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem.

# %% [markdown]
# What is a model and why would we want to use one? In this case, a model is going to be a neural network that attempts to learn the dynamics of the real environment. For example, in the CartPole we would like a model to be able to predict the next position of the Cart given the previous position and an action. By learning an accurate model, we can train our agent using the model rather than requiring to use the real environment every time. While this may seem less useful when the real environment is itself a simulation, like in our CartPole task, it can have huge advantages when attempting to learn policies for acting in the physical world.

# %% [markdown]
# How are we going to accomplish this in Tensorflow? We are going to be using a neural network that will learn the transition dynamics between a previous observation and action, and the expected new observation, reward, and done state. Our training procedure will involve switching between training our model using the real environment, and training our agent’s policy using the model environment. By using this approach we will be able to learn a policy that allows our agent to solve the CartPole task without actually ever training the policy on the real environment!

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]

################################################################################
# TODO: Implement the loss function.                                           #
# This sends the weights in the direction of making actions that gave good     #
# advantage (reward overtime) more likely, and actions that didn't less likely.#
################################################################################
pass
loglik = tf.log(input_y * (input_y - probability) + (1 - input_y) * (input_y + probability))
loss = -tf.reduce_mean(loglik * advantages)
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    ################################################################################
    # TODO: Implement the discounted rewards function                              #
    # Return discounted rewards weighed by gamma. Each reward will be replaced     #
    # with a weight reward that involves itself and all the other rewards occuring #
    # after it. The later the reward after it happens, the less effect it has on   #
    # the current rewards's discounted reward                                      #
    # Hint: [r0, r1, r2, ..., r_N] will look someting like:                        #
    #       [(r0 + r1*gamma^1 + ... r_N*gamma^N), (r1 + r2*gamma^1 + ...), ...]    #
    ################################################################################
    pass   
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r
    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                
                ################################################################################
                # TODO: Run the model network and compute predicted_state                      #
                # Output: 'pState'                                                             #
                ################################################################################
                pass
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs, actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts, rewards, dones])
                feed_dict = {previous_state: state_prevs, true_observation: state_nexts, true_done: dones, true_reward: rewards}
                loss, pState, _ = sess.run([model_loss, predicted_state, updateModel], feed_dict)
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                

            if trainThePolicy == True:
                
                ################################################################################
                # TODO: Run the policy network and compute newGrads                            #
                # Output: 'tGrad'                                                              #
                ################################################################################
                pass
                # compute the discounted reward backwards through time
                discounted_epr = discount_rewards(epr)
                # size the rewards to be unit normal (helps control the gradient estimator variance)
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr //= np.std(discounted_epr)
                tGrad = sess.run(newGrads, feed_dict = {observations: epx, input_y: epy, advantages: discounted_epr})
                ################################################################################
                #                                 END OF YOUR CODE                             #
                ################################################################################
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    
                    ################################################################################
                    # TODO:                                                                        #
                    # (1) Run the policy network and update gradients                              #
                    # (2) Reset gradBuffer to 0                                                    #
                    ################################################################################
                    pass    
                    sess.run(updateGrads, feed_dict = {W1Grad: gradBuffer[0], W2Grad: gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes
                if episode_number > 100:
                    
                    ################################################################################
                    # TODO: Alternating between training the policy from the model and training    #
                    # the model from the real environment.                                         #
                    ################################################################################
                    pass
                    drawFromModel = not drawFromModel 
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
                    ################################################################################
                    #                                 END OF YOUR CODE                             #
                    ################################################################################
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 19.333333. action: 0.000000. mean reward 19.333333.
# World Perf: Episode 7.000000. Reward 13.000000. action: 1.000000. mean reward 19.270000.
# World Perf: Episode 10.000000. Reward 20.000000. action: 0.000000. mean reward 19.277300.
# World Perf: Episode 13.000000. Reward 17.666667. action: 0.000000. mean reward 19.261194.
# World Perf: Episode 16.000000. Reward 31.000000. action: 1.000000. mean reward 19.378582.
# World Perf: Episode 19.000000. Reward 30.333333. action: 0.000000. mean reward 19.488129.
# World Perf: Episode 22.000000. Reward 15.333333. action: 1.000000. mean reward 19.446581.
# World Perf: Episode 25.000000. Reward 22.666667. action: 1.000000. mean reward 19.478782.
# World Perf: Episode 28.000000. Reward 22.000000. action: 0.000000. mean reward 19.503994.
# World Perf: Episode 31.000000. Reward 21.333333. action: 0.000000. mean reward 19.522288.
# World Perf: Episode 34.000000. Reward 28.000000. action: 1.000000. mean reward 19.607065.
# World Perf: Episode 37.000000. Reward 16.333333. action: 0.000000. mean reward 19.574328.
# World Perf: Episode 40.000000. Reward 35.000000. action: 0.000000. mean reward 19.728584.
# World Perf: Episode 43.000000. Reward 25.666667. action: 1.000000. mean reward 19.787965.
# World Perf: Episode 46.000000. Reward 22.666667. action: 1.000000. mean reward 19.816752.
# World Perf: Episode 49.000000. Reward 23.000000. action: 0.000000. mean reward 19.848585.
# World Perf: Episode 52.000000. Reward 20.000000. action: 1.000000. mean reward 19.850099.
# World Perf: Episode 55.000000. Reward 19.666667. action: 0.000000. mean reward 19.848264.
# World Perf: Episode 58.000000. Reward 17.333333. action: 1.000000. mean reward 19.823115.
# World Perf: Episode 61.000000. Reward 21.333333. action: 0.000000. mean reward 19.838217.
# World Perf: Episode 64.000000. Reward 22.333333. action: 0.000000. mean reward 19.863168.
# World Perf: Episode 67.000000. Reward 32.666667. action: 0.000000. mean reward 19.991203.
# World Perf: Episode 70.000000. Reward 19.000000. action: 0.000000. mean reward 19.981291.
# World Perf: Episode 73.000000. Reward 22.666667. action: 1.000000. mean reward 20.008145.
# World Perf: Episode 76.000000. Reward 33.000000. action: 0.000000. mean reward 20.138064.
# World Perf: Episode 79.000000. Reward 31.000000. action: 0.000000. mean reward 20.246683.
# World Perf: Episode 82.000000. Reward 44.333333. action: 0.000000. mean reward 20.487550.
# World Perf: Episode 85.000000. Reward 31.333333. action: 1.000000. mean reward 20.596007.
# World Perf: Episode 88.000000. Reward 25.000000. action: 0.000000. mean reward 20.640047.
# World Perf: Episode 91.000000. Reward 25.666667. action: 0.000000. mean reward 20.690314.
# World Perf: Episode 94.000000. Reward 19.333333. action: 0.000000. mean reward 20.676744.
# World Perf: Episode 97.000000. Reward 16.000000. action: 0.000000. mean reward 20.629976.
# World Perf: Episode 100.000000. Reward 31.000000. action: 1.000000. mean reward 20.733677.
# World Perf: Episode 103.000000. Reward 23.666667. action: 1.000000. mean reward 20.763006.
# World Perf: Episode 106.000000. Reward 18.333333. action: 0.000000. mean reward 20.619226.
# World Perf: Episode 109.000000. Reward 33.000000. action: 1.000000. mean reward 20.643726.
# World Perf: Episode 112.000000. Reward 27.666667. action: 0.000000. mean reward 20.593807.
# World Perf: Episode 115.000000. Reward 13.333333. action: 1.000000. mean reward 20.663321.
# World Perf: Episode 118.000000. Reward 26.333333. action: 1.000000. mean reward 20.592310.
# World Perf: Episode 121.000000. Reward 21.000000. action: 0.000000. mean reward 20.471945.
# World Perf: Episode 124.000000. Reward 20.000000. action: 1.000000. mean reward 20.354208.
# World Perf: Episode 127.000000. Reward 29.666667. action: 0.000000. mean reward 20.284702.
# World Perf: Episode 130.000000. Reward 21.000000. action: 0.000000. mean reward 20.329708.
# World Perf: Episode 133.000000. Reward 27.666667. action: 1.000000. mean reward 20.689022.
# World Perf: Episode 136.000000. Reward 22.666667. action: 1.000000. mean reward 21.744141.
# World Perf: Episode 139.000000. Reward 31.000000. action: 1.000000. mean reward 21.738312.
# World Perf: Episode 142.000000. Reward 37.333333. action: 0.000000. mean reward 21.731674.
# World Perf: Episode 145.000000. Reward 30.666667. action: 1.000000. mean reward 21.764421.
# World Perf: Episode 148.000000. Reward 16.333333. action: 1.000000. mean reward 23.735741.
# World Perf: Episode 151.000000. Reward 31.666667. action: 1.000000. mean reward 24.681028.
# World Perf: Episode 154.000000. Reward 34.000000. action: 1.000000. mean reward 26.612497.
# World Perf: Episode 157.000000. Reward 24.666667. action: 0.000000. mean reward 26.650635.
# World Perf: Episode 160.000000. Reward 34.666667. action: 0.000000. mean reward 26.662827.
# World Perf: Episode 163.000000. Reward 19.333333. action: 1.000000. mean reward 26.841629.
# World Perf: Episode 166.000000. Reward 35.666667. action: 0.000000. mean reward 26.919542.
# World Perf: Episode 169.000000. Reward 18.333333. action: 0.000000. mean reward 26.659800.
# World Perf: Episode 172.000000. Reward 34.666667. action: 1.000000. mean reward 26.652235.
# World Perf: Episode 175.000000. Reward 18.333333. action: 0.000000. mean reward 26.942236.
# World Perf: Episode 178.000000. Reward 25.333333. action: 1.000000. mean reward 26.777639.
# World Perf: Episode 181.000000. Reward 36.000000. action: 1.000000. mean reward 27.140352.
# World Perf: Episode 184.000000. Reward 28.666667. action: 0.000000. mean reward 27.039877.
# World Perf: Episode 187.000000. Reward 22.000000. action: 1.000000. mean reward 26.917631.
# World Perf: Episode 190.000000. Reward 14.333333. action: 1.000000. mean reward 26.666298.
# World Perf: Episode 193.000000. Reward 46.333333. action: 0.000000. mean reward 26.710665.
# World Perf: Episode 196.000000. Reward 28.666667. action: 0.000000. mean reward 26.564199.
# World Perf: Episode 199.000000. Reward 14.333333. action: 1.000000. mean reward 26.231138.
# World Perf: Episode 202.000000. Reward 33.666667. action: 1.000000. mean reward 26.152941.
# World Perf: Episode 205.000000. Reward 26.666667. action: 0.000000. mean reward 26.007998.
# World Perf: Episode 208.000000. Reward 21.666667. action: 1.000000. mean reward 26.076548.
# World Perf: Episode 211.000000. Reward 38.333333. action: 1.000000. mean reward 26.041740.
# World Perf: Episode 214.000000. Reward 23.666667. action: 0.000000. mean reward 26.127083.
# World Perf: Episode 217.000000. Reward 25.000000. action: 0.000000. mean reward 25.964249.
# World Perf: Episode 220.000000. Reward 34.666667. action: 0.000000. mean reward 26.373383.
# World Perf: Episode 223.000000. Reward 27.666667. action: 1.000000. mean reward 26.697695.
# World Perf: Episode 226.000000. Reward 25.333333. action: 0.000000. mean reward 26.659348.
# World Perf: Episode 229.000000. Reward 26.000000. action: 0.000000. mean reward 26.434587.
# World Perf: Episode 232.000000. Reward 18.666667. action: 1.000000. mean reward 26.167015.
# World Perf: Episode 235.000000. Reward 29.000000. action: 0.000000. mean reward 26.001146.
# World Perf: Episode 238.000000. Reward 22.333333. action: 1.000000. mean reward 27.080330.
# World Perf: Episode 241.000000. Reward 29.666667. action: 0.000000. mean reward 27.271208.
# World Perf: Episode 244.000000. Reward 21.666667. action: 1.000000. mean reward 27.053787.
# World Perf: Episode 247.000000. Reward 26.333333. action: 0.000000. mean reward 26.860428.
# World Perf: Episode 250.000000. Reward 19.000000. action: 0.000000. mean reward 27.109426.
# World Perf: Episode 253.000000. Reward 32.666667. action: 0.000000. mean reward 27.096230.
# World Perf: Episode 256.000000. Reward 45.333333. action: 1.000000. mean reward 27.110687.
# World Perf: Episode 259.000000. Reward 26.000000. action: 0.000000. mean reward 27.119423.
# World Perf: Episode 262.000000. Reward 26.333333. action: 1.000000. mean reward 27.304535.
# World Perf: Episode 265.000000. Reward 38.000000. action: 0.000000. mean reward 27.421461.
# World Perf: Episode 268.000000. Reward 46.333333. action: 0.000000. mean reward 27.818624.
# World Perf: Episode 271.000000. Reward 26.666667. action: 0.000000. mean reward 27.696985.
# World Perf: Episode 274.000000. Reward 21.000000. action: 0.000000. mean reward 27.503145.
# World Perf: Episode 277.000000. Reward 25.666667. action: 1.000000. mean reward 27.264090.
# World Perf: Episode 280.000000. Reward 36.666667. action: 1.000000. mean reward 27.291031.
# World Perf: Episode 283.000000. Reward 32.000000. action: 0.000000. mean reward 27.165281.
# World Perf: Episode 286.000000. Reward 18.000000. action: 0.000000. mean reward 27.160326.
# World Perf: Episode 289.000000. Reward 33.333333. action: 0.000000. mean reward 27.294800.
# World Perf: Episode 292.000000. Reward 32.000000. action: 1.000000. mean reward 27.195440.
# World Perf: Episode 295.000000. Reward 24.000000. action: 0.000000. mean reward 26.964661.
# World Perf: Episode 298.000000. Reward 27.666667. action: 1.000000. mean reward 26.948708.
# World Perf: Episode 301.000000. Reward 25.666667. action: 1.000000. mean reward 27.182852.
# World Perf: Episode 304.000000. Reward 33.000000. action: 0.000000. mean reward 27.160454.
# World Perf: Episode 307.000000. Reward 23.000000. action: 0.000000. mean reward 26.959166.
# World Perf: Episode 310.000000. Reward 33.000000. action: 1.000000. mean reward 26.856199.
# World Perf: Episode 313.000000. Reward 35.666667. action: 1.000000. mean reward 26.758553.
# World Perf: Episode 316.000000. Reward 30.666667. action: 1.000000. mean reward 26.574789.
# World Perf: Episode 319.000000. Reward 25.000000. action: 1.000000. mean reward 29.286688.
# World Perf: Episode 322.000000. Reward 29.000000. action: 1.000000. mean reward 30.762344.
# World Perf: Episode 325.000000. Reward 69.000000. action: 1.000000. mean reward 34.518505.
# World Perf: Episode 328.000000. Reward 21.666667. action: 0.000000. mean reward 40.590420.
# World Perf: Episode 331.000000. Reward 28.333333. action: 1.000000. mean reward 43.611813.
# World Perf: Episode 334.000000. Reward 25.333333. action: 0.000000. mean reward 43.136234.
# World Perf: Episode 337.000000. Reward 75.000000. action: 0.000000. mean reward 43.206650.
# World Perf: Episode 340.000000. Reward 18.333333. action: 0.000000. mean reward 42.852779.
# World Perf: Episode 343.000000. Reward 42.333333. action: 1.000000. mean reward 42.857067.
# World Perf: Episode 346.000000. Reward 39.000000. action: 1.000000. mean reward 46.067902.
# World Perf: Episode 349.000000. Reward 32.000000. action: 0.000000. mean reward 58.414989.
# World Perf: Episode 352.000000. Reward 24.333333. action: 1.000000. mean reward 62.291317.
# World Perf: Episode 355.000000. Reward 26.000000. action: 0.000000. mean reward 62.287994.
# World Perf: Episode 358.000000. Reward 26.333333. action: 1.000000. mean reward 61.469051.
# World Perf: Episode 361.000000. Reward 27.666667. action: 1.000000. mean reward 86.569847.
# World Perf: Episode 364.000000. Reward 44.666667. action: 1.000000. mean reward 88.384674.
# World Perf: Episode 367.000000. Reward 27.000000. action: 1.000000. mean reward 110.191841.
# World Perf: Episode 370.000000. Reward 28.666667. action: 0.000000. mean reward 109.314995.
# World Perf: Episode 373.000000. Reward 43.000000. action: 1.000000. mean reward 107.793709.
# World Perf: Episode 376.000000. Reward 40.333333. action: 0.000000. mean reward 119.215157.
# World Perf: Episode 379.000000. Reward 40.000000. action: 1.000000. mean reward 117.519753.
# World Perf: Episode 382.000000. Reward 34.000000. action: 0.000000. mean reward 115.641167.
# World Perf: Episode 385.000000. Reward 26.000000. action: 1.000000. mean reward 133.980499.
# World Perf: Episode 388.000000. Reward 25.000000. action: 1.000000. mean reward 131.701141.
# World Perf: Episode 391.000000. Reward 33.000000. action: 1.000000. mean reward 129.708328.
# World Perf: Episode 394.000000. Reward 42.333333. action: 0.000000. mean reward 128.229889.
# World Perf: Episode 397.000000. Reward 61.666667. action: 0.000000. mean reward 126.728142.
# World Perf: Episode 400.000000. Reward 54.333333. action: 0.000000. mean reward 130.413818.
# World Perf: Episode 403.000000. Reward 86.333333. action: 1.000000. mean reward 129.817688.
# World Perf: Episode 406.000000. Reward 47.333333. action: 0.000000. mean reward 127.731323.
# World Perf: Episode 409.000000. Reward 20.333333. action: 0.000000. mean reward 125.418427.
# World Perf: Episode 412.000000. Reward 38.666667. action: 0.000000. mean reward 123.354591.
# World Perf: Episode 415.000000. Reward 43.000000. action: 0.000000. mean reward 121.351952.
# World Perf: Episode 418.000000. Reward 44.333333. action: 1.000000. mean reward 119.407898.
# World Perf: Episode 421.000000. Reward 47.333333. action: 1.000000. mean reward 117.681633.
# World Perf: Episode 424.000000. Reward 30.000000. action: 0.000000. mean reward 115.669800.
# World Perf: Episode 427.000000. Reward 61.333333. action: 0.000000. mean reward 114.029701.
# World Perf: Episode 430.000000. Reward 32.666667. action: 1.000000. mean reward 112.119759.
# World Perf: Episode 433.000000. Reward 57.000000. action: 1.000000. mean reward 110.523109.
# World Perf: Episode 436.000000. Reward 52.666667. action: 1.000000. mean reward 108.965096.
# World Perf: Episode 439.000000. Reward 51.333333. action: 1.000000. mean reward 107.367859.
# World Perf: Episode 442.000000. Reward 61.000000. action: 0.000000. mean reward 105.944725.
# World Perf: Episode 445.000000. Reward 45.333333. action: 0.000000. mean reward 104.363197.
# World Perf: Episode 448.000000. Reward 43.000000. action: 0.000000. mean reward 103.830101.
# World Perf: Episode 451.000000. Reward 28.333333. action: 1.000000. mean reward 104.988640.
# World Perf: Episode 454.000000. Reward 35.666667. action: 1.000000. mean reward 103.467339.
# World Perf: Episode 457.000000. Reward 57.333333. action: 0.000000. mean reward 102.987556.
# World Perf: Episode 460.000000. Reward 75.000000. action: 1.000000. mean reward 104.627586.
# World Perf: Episode 463.000000. Reward 40.333333. action: 1.000000. mean reward 103.030403.
# World Perf: Episode 466.000000. Reward 32.666667. action: 0.000000. mean reward 101.457397.
# World Perf: Episode 469.000000. Reward 60.666667. action: 1.000000. mean reward 100.270210.
# World Perf: Episode 472.000000. Reward 60.000000. action: 0.000000. mean reward 98.959961.
# World Perf: Episode 475.000000. Reward 29.000000. action: 1.000000. mean reward 97.717705.
# World Perf: Episode 478.000000. Reward 63.000000. action: 1.000000. mean reward 97.849609.
# World Perf: Episode 481.000000. Reward 33.333333. action: 1.000000. mean reward 96.501472.
# World Perf: Episode 484.000000. Reward 29.666667. action: 0.000000. mean reward 95.016052.
# World Perf: Episode 487.000000. Reward 51.000000. action: 1.000000. mean reward 94.050224.
# World Perf: Episode 490.000000. Reward 101.666667. action: 0.000000. mean reward 93.590614.
# World Perf: Episode 493.000000. Reward 37.666667. action: 1.000000. mean reward 95.722649.
# World Perf: Episode 496.000000. Reward 41.666667. action: 0.000000. mean reward 94.917480.
# World Perf: Episode 499.000000. Reward 31.333333. action: 0.000000. mean reward 93.444817.
# World Perf: Episode 502.000000. Reward 22.000000. action: 0.000000. mean reward 92.008385.
# World Perf: Episode 505.000000. Reward 45.000000. action: 0.000000. mean reward 90.682961.
# World Perf: Episode 508.000000. Reward 42.333333. action: 0.000000. mean reward 89.536476.
# World Perf: Episode 511.000000. Reward 58.000000. action: 1.000000. mean reward 91.243523.
# World Perf: Episode 514.000000. Reward 46.333333. action: 1.000000. mean reward 92.984123.
# World Perf: Episode 517.000000. Reward 38.333333. action: 1.000000. mean reward 91.898293.
# World Perf: Episode 520.000000. Reward 38.000000. action: 1.000000. mean reward 90.600128.
# World Perf: Episode 523.000000. Reward 52.666667. action: 0.000000. mean reward 91.648438.
# World Perf: Episode 526.000000. Reward 29.000000. action: 1.000000. mean reward 92.799324.
# World Perf: Episode 529.000000. Reward 31.333333. action: 1.000000. mean reward 93.327515.
# World Perf: Episode 532.000000. Reward 50.333333. action: 1.000000. mean reward 95.039062.
# World Perf: Episode 535.000000. Reward 54.000000. action: 0.000000. mean reward 94.988884.
# World Perf: Episode 538.000000. Reward 68.000000. action: 1.000000. mean reward 94.508141.
# World Perf: Episode 541.000000. Reward 39.333333. action: 0.000000. mean reward 93.550598.
# World Perf: Episode 544.000000. Reward 85.333333. action: 1.000000. mean reward 92.781525.
# World Perf: Episode 547.000000. Reward 52.333333. action: 0.000000. mean reward 91.662079.
# World Perf: Episode 550.000000. Reward 61.666667. action: 0.000000. mean reward 91.186790.
# World Perf: Episode 553.000000. Reward 31.333333. action: 0.000000. mean reward 90.563545.
# World Perf: Episode 556.000000. Reward 115.666667. action: 0.000000. mean reward 90.111664.
# World Perf: Episode 559.000000. Reward 59.333333. action: 1.000000. mean reward 89.249481.
# World Perf: Episode 562.000000. Reward 56.333333. action: 0.000000. mean reward 92.317566.
# World Perf: Episode 565.000000. Reward 35.000000. action: 0.000000. mean reward 90.916260.
# World Perf: Episode 568.000000. Reward 38.000000. action: 1.000000. mean reward 89.668480.
# World Perf: Episode 571.000000. Reward 36.666667. action: 1.000000. mean reward 88.755684.
# World Perf: Episode 574.000000. Reward 33.000000. action: 1.000000. mean reward 87.642403.
# World Perf: Episode 577.000000. Reward 49.666667. action: 0.000000. mean reward 89.120506.
# World Perf: Episode 580.000000. Reward 30.666667. action: 0.000000. mean reward 90.723022.
# World Perf: Episode 583.000000. Reward 51.000000. action: 1.000000. mean reward 91.440529.
# World Perf: Episode 586.000000. Reward 65.000000. action: 0.000000. mean reward 91.041145.
# World Perf: Episode 589.000000. Reward 46.666667. action: 0.000000. mean reward 92.390739.
# World Perf: Episode 592.000000. Reward 71.666667. action: 0.000000. mean reward 94.865356.
# World Perf: Episode 595.000000. Reward 40.666667. action: 0.000000. mean reward 95.049095.
# World Perf: Episode 598.000000. Reward 40.000000. action: 1.000000. mean reward 95.720497.
# World Perf: Episode 601.000000. Reward 45.666667. action: 0.000000. mean reward 97.299561.
# World Perf: Episode 604.000000. Reward 35.333333. action: 1.000000. mean reward 101.624336.
# World Perf: Episode 607.000000. Reward 41.666667. action: 0.000000. mean reward 106.249481.
# World Perf: Episode 610.000000. Reward 136.000000. action: 0.000000. mean reward 105.767517.
# World Perf: Episode 613.000000. Reward 48.333333. action: 0.000000. mean reward 105.692719.
# World Perf: Episode 616.000000. Reward 51.333333. action: 0.000000. mean reward 104.312828.
# World Perf: Episode 619.000000. Reward 56.333333. action: 1.000000. mean reward 105.784454.
# World Perf: Episode 622.000000. Reward 43.666667. action: 0.000000. mean reward 104.372131.
# World Perf: Episode 625.000000. Reward 59.666667. action: 0.000000. mean reward 104.320740.
# World Perf: Episode 628.000000. Reward 93.333333. action: 0.000000. mean reward 105.129883.
# World Perf: Episode 631.000000. Reward 67.000000. action: 0.000000. mean reward 104.298553.
# World Perf: Episode 634.000000. Reward 61.666667. action: 0.000000. mean reward 103.388298.
# World Perf: Episode 637.000000. Reward 44.666667. action: 1.000000. mean reward 102.773262.
# World Perf: Episode 640.000000. Reward 62.000000. action: 0.000000. mean reward 104.272186.
# World Perf: Episode 643.000000. Reward 37.333333. action: 0.000000. mean reward 105.096840.
# World Perf: Episode 646.000000. Reward 59.333333. action: 1.000000. mean reward 106.610146.
# World Perf: Episode 649.000000. Reward 35.666667. action: 1.000000. mean reward 106.615700.
# World Perf: Episode 652.000000. Reward 68.333333. action: 0.000000. mean reward 105.563965.
# World Perf: Episode 655.000000. Reward 41.666667. action: 0.000000. mean reward 104.146217.
# World Perf: Episode 658.000000. Reward 89.000000. action: 0.000000. mean reward 105.917519.
# World Perf: Episode 661.000000. Reward 83.333333. action: 1.000000. mean reward 105.109039.
# World Perf: Episode 664.000000. Reward 44.666667. action: 0.000000. mean reward 106.398315.
# World Perf: Episode 667.000000. Reward 56.333333. action: 0.000000. mean reward 105.017113.
# World Perf: Episode 670.000000. Reward 66.000000. action: 0.000000. mean reward 106.599548.
# World Perf: Episode 673.000000. Reward 129.333333. action: 0.000000. mean reward 106.143166.
# World Perf: Episode 676.000000. Reward 54.666667. action: 0.000000. mean reward 104.693504.
# World Perf: Episode 679.000000. Reward 79.333333. action: 0.000000. mean reward 103.534950.
# World Perf: Episode 682.000000. Reward 63.333333. action: 1.000000. mean reward 102.283348.
# World Perf: Episode 685.000000. Reward 35.333333. action: 0.000000. mean reward 100.700409.
# World Perf: Episode 688.000000. Reward 67.333333. action: 0.000000. mean reward 99.672951.
# World Perf: Episode 691.000000. Reward 72.666667. action: 1.000000. mean reward 98.811668.
# World Perf: Episode 694.000000. Reward 51.666667. action: 0.000000. mean reward 97.478210.
# World Perf: Episode 697.000000. Reward 57.000000. action: 0.000000. mean reward 99.015465.
# World Perf: Episode 700.000000. Reward 50.000000. action: 0.000000. mean reward 100.498024.
# World Perf: Episode 703.000000. Reward 101.333333. action: 1.000000. mean reward 99.667732.
# World Perf: Episode 706.000000. Reward 79.333333. action: 1.000000. mean reward 98.921898.
# World Perf: Episode 709.000000. Reward 30.666667. action: 1.000000. mean reward 100.164978.
# World Perf: Episode 712.000000. Reward 39.666667. action: 1.000000. mean reward 98.619995.
# World Perf: Episode 715.000000. Reward 63.666667. action: 0.000000. mean reward 97.635521.
# World Perf: Episode 718.000000. Reward 101.333333. action: 1.000000. mean reward 97.137642.
# World Perf: Episode 721.000000. Reward 65.333333. action: 0.000000. mean reward 95.933167.
# World Perf: Episode 724.000000. Reward 65.666667. action: 0.000000. mean reward 94.999672.
# World Perf: Episode 727.000000. Reward 78.666667. action: 0.000000. mean reward 94.009087.
# World Perf: Episode 730.000000. Reward 78.333333. action: 0.000000. mean reward 93.025520.
# World Perf: Episode 733.000000. Reward 72.000000. action: 0.000000. mean reward 92.019386.
# World Perf: Episode 736.000000. Reward 42.000000. action: 1.000000. mean reward 90.728737.
# World Perf: Episode 739.000000. Reward 63.666667. action: 1.000000. mean reward 90.159935.
# World Perf: Episode 742.000000. Reward 56.666667. action: 0.000000. mean reward 89.068428.
# World Perf: Episode 745.000000. Reward 37.000000. action: 1.000000. mean reward 90.666870.
# World Perf: Episode 748.000000. Reward 42.000000. action: 1.000000. mean reward 92.280487.
# World Perf: Episode 751.000000. Reward 67.000000. action: 0.000000. mean reward 91.590752.
# World Perf: Episode 754.000000. Reward 55.000000. action: 0.000000. mean reward 93.364532.
# World Perf: Episode 757.000000. Reward 61.000000. action: 1.000000. mean reward 93.418053.
# World Perf: Episode 760.000000. Reward 52.000000. action: 0.000000. mean reward 92.365776.
# World Perf: Episode 763.000000. Reward 62.000000. action: 0.000000. mean reward 93.504890.
# World Perf: Episode 766.000000. Reward 43.666667. action: 1.000000. mean reward 92.695869.
# World Perf: Episode 769.000000. Reward 73.000000. action: 0.000000. mean reward 94.462555.
# World Perf: Episode 772.000000. Reward 71.333333. action: 0.000000. mean reward 93.716072.
# World Perf: Episode 775.000000. Reward 64.666667. action: 1.000000. mean reward 93.866272.
# World Perf: Episode 778.000000. Reward 45.333333. action: 0.000000. mean reward 94.297890.
# World Perf: Episode 781.000000. Reward 33.666667. action: 0.000000. mean reward 95.804115.
# World Perf: Episode 784.000000. Reward 92.000000. action: 1.000000. mean reward 95.013123.
# World Perf: Episode 787.000000. Reward 67.666667. action: 0.000000. mean reward 94.446320.
# World Perf: Episode 790.000000. Reward 103.333333. action: 0.000000. mean reward 93.889320.
# World Perf: Episode 793.000000. Reward 73.333333. action: 0.000000. mean reward 93.401733.
# World Perf: Episode 796.000000. Reward 61.666667. action: 0.000000. mean reward 94.011757.
# World Perf: Episode 799.000000. Reward 61.666667. action: 0.000000. mean reward 93.125603.
# World Perf: Episode 802.000000. Reward 71.000000. action: 0.000000. mean reward 93.289284.
# World Perf: Episode 805.000000. Reward 62.333333. action: 1.000000. mean reward 92.199181.
# World Perf: Episode 808.000000. Reward 61.666667. action: 0.000000. mean reward 91.297852.
# World Perf: Episode 811.000000. Reward 92.666667. action: 1.000000. mean reward 90.610832.
# World Perf: Episode 814.000000. Reward 103.666667. action: 0.000000. mean reward 90.320038.
# World Perf: Episode 817.000000. Reward 55.333333. action: 0.000000. mean reward 89.329979.
# World Perf: Episode 820.000000. Reward 51.666667. action: 1.000000. mean reward 88.484444.
# World Perf: Episode 823.000000. Reward 48.333333. action: 0.000000. mean reward 87.754242.
# World Perf: Episode 826.000000. Reward 54.666667. action: 1.000000. mean reward 87.012108.
# World Perf: Episode 829.000000. Reward 65.666667. action: 0.000000. mean reward 86.554192.
# World Perf: Episode 832.000000. Reward 58.333333. action: 0.000000. mean reward 86.313477.
# World Perf: Episode 835.000000. Reward 82.000000. action: 1.000000. mean reward 85.760193.
# World Perf: Episode 838.000000. Reward 58.333333. action: 1.000000. mean reward 86.987213.
# World Perf: Episode 841.000000. Reward 53.333333. action: 1.000000. mean reward 85.958435.
# World Perf: Episode 844.000000. Reward 73.666667. action: 1.000000. mean reward 85.383598.
# World Perf: Episode 847.000000. Reward 80.666667. action: 1.000000. mean reward 84.667534.
# World Perf: Episode 850.000000. Reward 63.000000. action: 0.000000. mean reward 83.924873.
# World Perf: Episode 853.000000. Reward 55.666667. action: 1.000000. mean reward 83.754433.
# World Perf: Episode 856.000000. Reward 80.333333. action: 1.000000. mean reward 83.130287.
# World Perf: Episode 859.000000. Reward 65.666667. action: 0.000000. mean reward 82.535637.
# World Perf: Episode 862.000000. Reward 50.666667. action: 0.000000. mean reward 82.990852.
# World Perf: Episode 865.000000. Reward 55.666667. action: 0.000000. mean reward 82.101433.
# World Perf: Episode 868.000000. Reward 72.666667. action: 1.000000. mean reward 81.496704.
# World Perf: Episode 871.000000. Reward 70.333333. action: 0.000000. mean reward 80.973427.
# World Perf: Episode 874.000000. Reward 63.000000. action: 1.000000. mean reward 80.338844.
# World Perf: Episode 877.000000. Reward 62.000000. action: 1.000000. mean reward 79.535545.
# World Perf: Episode 880.000000. Reward 70.666667. action: 1.000000. mean reward 79.300316.
# World Perf: Episode 883.000000. Reward 68.000000. action: 0.000000. mean reward 78.628944.
# World Perf: Episode 886.000000. Reward 69.666667. action: 1.000000. mean reward 77.881760.
# World Perf: Episode 889.000000. Reward 49.666667. action: 0.000000. mean reward 77.411346.
# World Perf: Episode 892.000000. Reward 92.000000. action: 0.000000. mean reward 76.979385.
# World Perf: Episode 895.000000. Reward 70.000000. action: 1.000000. mean reward 76.290749.
# World Perf: Episode 898.000000. Reward 58.666667. action: 1.000000. mean reward 75.620644.
# World Perf: Episode 901.000000. Reward 36.000000. action: 0.000000. mean reward 74.803772.
# World Perf: Episode 904.000000. Reward 91.000000. action: 0.000000. mean reward 74.527687.
# World Perf: Episode 907.000000. Reward 127.333333. action: 0.000000. mean reward 76.768250.
# World Perf: Episode 910.000000. Reward 111.333333. action: 0.000000. mean reward 79.289986.
# World Perf: Episode 913.000000. Reward 85.666667. action: 1.000000. mean reward 78.950394.
# World Perf: Episode 916.000000. Reward 95.000000. action: 1.000000. mean reward 81.293861.
# World Perf: Episode 919.000000. Reward 65.333333. action: 0.000000. mean reward 80.693924.
# World Perf: Episode 922.000000. Reward 88.000000. action: 0.000000. mean reward 80.189690.
# World Perf: Episode 925.000000. Reward 57.333333. action: 1.000000. mean reward 79.382889.
# World Perf: Episode 928.000000. Reward 74.333333. action: 0.000000. mean reward 78.684875.
# World Perf: Episode 931.000000. Reward 90.000000. action: 1.000000. mean reward 78.256882.
# World Perf: Episode 934.000000. Reward 100.000000. action: 0.000000. mean reward 77.984413.
# World Perf: Episode 937.000000. Reward 77.666667. action: 1.000000. mean reward 77.423340.
# World Perf: Episode 940.000000. Reward 84.666667. action: 0.000000. mean reward 76.897652.
# World Perf: Episode 943.000000. Reward 42.333333. action: 0.000000. mean reward 76.096336.
# World Perf: Episode 946.000000. Reward 68.333333. action: 0.000000. mean reward 75.412926.
# World Perf: Episode 949.000000. Reward 106.000000. action: 0.000000. mean reward 75.105835.
# World Perf: Episode 952.000000. Reward 62.333333. action: 0.000000. mean reward 74.682091.
# World Perf: Episode 955.000000. Reward 59.666667. action: 1.000000. mean reward 74.335052.
# World Perf: Episode 958.000000. Reward 61.666667. action: 0.000000. mean reward 76.133766.
# World Perf: Episode 961.000000. Reward 68.666667. action: 0.000000. mean reward 75.453148.
# World Perf: Episode 964.000000. Reward 89.666667. action: 1.000000. mean reward 77.040115.
# World Perf: Episode 967.000000. Reward 91.666667. action: 1.000000. mean reward 76.538788.
# World Perf: Episode 970.000000. Reward 54.000000. action: 0.000000. mean reward 75.675491.
# World Perf: Episode 973.000000. Reward 54.333333. action: 0.000000. mean reward 75.311806.
# World Perf: Episode 976.000000. Reward 77.333333. action: 0.000000. mean reward 74.707260.
# World Perf: Episode 979.000000. Reward 82.666667. action: 1.000000. mean reward 74.157242.
# World Perf: Episode 982.000000. Reward 77.666667. action: 1.000000. mean reward 73.830177.
# World Perf: Episode 985.000000. Reward 89.333333. action: 0.000000. mean reward 73.406357.
# World Perf: Episode 988.000000. Reward 69.333333. action: 0.000000. mean reward 72.833893.
# World Perf: Episode 991.000000. Reward 59.333333. action: 0.000000. mean reward 72.086586.
# World Perf: Episode 994.000000. Reward 61.000000. action: 0.000000. mean reward 71.482307.
# World Perf: Episode 997.000000. Reward 63.000000. action: 1.000000. mean reward 70.846413.
# World Perf: Episode 1000.000000. Reward 64.333333. action: 0.000000. mean reward 70.393936.
# World Perf: Episode 1003.000000. Reward 55.333333. action: 0.000000. mean reward 69.959503.
# World Perf: Episode 1006.000000. Reward 54.333333. action: 1.000000. mean reward 70.201332.
# World Perf: Episode 1009.000000. Reward 44.000000. action: 0.000000. mean reward 71.257607.
# World Perf: Episode 1012.000000. Reward 89.000000. action: 1.000000. mean reward 72.177956.
# World Perf: Episode 1015.000000. Reward 76.666667. action: 1.000000. mean reward 71.969536.
# World Perf: Episode 1018.000000. Reward 93.000000. action: 0.000000. mean reward 71.813286.
# World Perf: Episode 1021.000000. Reward 72.000000. action: 0.000000. mean reward 71.647270.
# World Perf: Episode 1024.000000. Reward 113.333333. action: 0.000000. mean reward 71.590202.
# World Perf: Episode 1027.000000. Reward 50.333333. action: 0.000000. mean reward 70.890221.
# World Perf: Episode 1030.000000. Reward 107.333333. action: 0.000000. mean reward 70.730797.
# World Perf: Episode 1033.000000. Reward 119.000000. action: 1.000000. mean reward 70.778511.
# World Perf: Episode 1036.000000. Reward 94.333333. action: 0.000000. mean reward 70.418846.
# World Perf: Episode 1039.000000. Reward 85.000000. action: 0.000000. mean reward 70.296562.
# World Perf: Episode 1042.000000. Reward 129.666667. action: 0.000000. mean reward 73.194328.
# World Perf: Episode 1045.000000. Reward 105.666667. action: 1.000000. mean reward 72.961273.
# World Perf: Episode 1048.000000. Reward 82.000000. action: 0.000000. mean reward 74.533646.
# World Perf: Episode 1051.000000. Reward 78.000000. action: 0.000000. mean reward 75.582016.
# World Perf: Episode 1054.000000. Reward 94.000000. action: 0.000000. mean reward 75.830742.
# World Perf: Episode 1057.000000. Reward 81.333333. action: 0.000000. mean reward 75.328255.
# World Perf: Episode 1060.000000. Reward 108.000000. action: 1.000000. mean reward 76.804489.
# World Perf: Episode 1063.000000. Reward 70.666667. action: 1.000000. mean reward 76.881798.
# World Perf: Episode 1066.000000. Reward 81.333333. action: 0.000000. mean reward 77.904182.
# World Perf: Episode 1069.000000. Reward 143.666667. action: 0.000000. mean reward 78.023468.
# World Perf: Episode 1072.000000. Reward 120.333333. action: 1.000000. mean reward 77.797157.
# World Perf: Episode 1075.000000. Reward 76.000000. action: 0.000000. mean reward 79.756294.
# World Perf: Episode 1078.000000. Reward 67.666667. action: 0.000000. mean reward 78.920815.
# World Perf: Episode 1081.000000. Reward 140.000000. action: 0.000000. mean reward 80.373909.
# World Perf: Episode 1084.000000. Reward 123.666667. action: 0.000000. mean reward 80.124138.
# World Perf: Episode 1087.000000. Reward 67.666667. action: 0.000000. mean reward 79.658089.
# World Perf: Episode 1090.000000. Reward 150.000000. action: 0.000000. mean reward 79.680687.
# World Perf: Episode 1093.000000. Reward 114.000000. action: 0.000000. mean reward 79.753601.
# World Perf: Episode 1096.000000. Reward 75.333333. action: 1.000000. mean reward 81.859062.
# World Perf: Episode 1099.000000. Reward 121.666667. action: 0.000000. mean reward 83.309654.
# World Perf: Episode 1102.000000. Reward 55.333333. action: 0.000000. mean reward 85.798439.
# World Perf: Episode 1105.000000. Reward 58.000000. action: 0.000000. mean reward 87.537666.
# World Perf: Episode 1108.000000. Reward 114.333333. action: 1.000000. mean reward 89.985023.
# World Perf: Episode 1111.000000. Reward 139.000000. action: 0.000000. mean reward 92.522285.
# World Perf: Episode 1114.000000. Reward 59.000000. action: 0.000000. mean reward 91.810493.
# World Perf: Episode 1117.000000. Reward 118.333333. action: 0.000000. mean reward 91.959068.
# World Perf: Episode 1120.000000. Reward 120.666667. action: 1.000000. mean reward 91.480736.
# World Perf: Episode 1123.000000. Reward 118.000000. action: 0.000000. mean reward 91.302582.
# World Perf: Episode 1126.000000. Reward 100.000000. action: 1.000000. mean reward 90.588829.
# World Perf: Episode 1129.000000. Reward 104.333333. action: 0.000000. mean reward 90.151093.
# World Perf: Episode 1132.000000. Reward 115.666667. action: 0.000000. mean reward 92.376274.
# World Perf: Episode 1135.000000. Reward 74.666667. action: 1.000000. mean reward 91.410866.
# World Perf: Episode 1138.000000. Reward 132.333333. action: 0.000000. mean reward 93.984192.
# World Perf: Episode 1141.000000. Reward 63.333333. action: 1.000000. mean reward 93.176689.
# World Perf: Episode 1144.000000. Reward 104.333333. action: 0.000000. mean reward 92.849586.
# World Perf: Episode 1147.000000. Reward 66.000000. action: 0.000000. mean reward 92.409813.
# World Perf: Episode 1150.000000. Reward 84.666667. action: 1.000000. mean reward 94.314308.
# World Perf: Episode 1153.000000. Reward 98.666667. action: 0.000000. mean reward 96.050873.
# World Perf: Episode 1156.000000. Reward 111.000000. action: 0.000000. mean reward 98.941078.
# World Perf: Episode 1159.000000. Reward 110.666667. action: 0.000000. mean reward 98.498352.
# World Perf: Episode 1162.000000. Reward 105.666667. action: 0.000000. mean reward 97.827728.
# World Perf: Episode 1165.000000. Reward 124.000000. action: 0.000000. mean reward 98.558754.
# World Perf: Episode 1168.000000. Reward 83.333333. action: 0.000000. mean reward 97.803108.
# World Perf: Episode 1171.000000. Reward 51.000000. action: 0.000000. mean reward 96.715416.
# World Perf: Episode 1174.000000. Reward 55.666667. action: 0.000000. mean reward 96.831856.
# World Perf: Episode 1177.000000. Reward 99.000000. action: 0.000000. mean reward 98.938660.
# World Perf: Episode 1180.000000. Reward 98.333333. action: 0.000000. mean reward 100.178734.
# World Perf: Episode 1183.000000. Reward 67.333333. action: 0.000000. mean reward 99.277840.
# World Perf: Episode 1186.000000. Reward 102.000000. action: 1.000000. mean reward 99.832855.
# World Perf: Episode 1189.000000. Reward 90.333333. action: 0.000000. mean reward 99.156555.
# World Perf: Episode 1192.000000. Reward 102.666667. action: 0.000000. mean reward 98.591743.
# World Perf: Episode 1195.000000. Reward 91.000000. action: 0.000000. mean reward 98.186371.
# World Perf: Episode 1198.000000. Reward 116.333333. action: 0.000000. mean reward 100.831505.
# World Perf: Episode 1201.000000. Reward 52.333333. action: 0.000000. mean reward 102.369118.
# World Perf: Episode 1204.000000. Reward 105.666667. action: 1.000000. mean reward 102.648689.
# World Perf: Episode 1207.000000. Reward 58.333333. action: 0.000000. mean reward 104.019135.
# World Perf: Episode 1210.000000. Reward 80.333333. action: 0.000000. mean reward 103.992310.
# World Perf: Episode 1213.000000. Reward 107.000000. action: 0.000000. mean reward 103.192696.
# World Perf: Episode 1216.000000. Reward 119.333333. action: 1.000000. mean reward 105.260315.
# World Perf: Episode 1219.000000. Reward 105.333333. action: 0.000000. mean reward 107.146088.
# World Perf: Episode 1222.000000. Reward 141.000000. action: 0.000000. mean reward 106.726654.
# World Perf: Episode 1225.000000. Reward 82.000000. action: 0.000000. mean reward 108.372284.
# World Perf: Episode 1228.000000. Reward 120.000000. action: 0.000000. mean reward 107.670845.
# World Perf: Episode 1231.000000. Reward 93.333333. action: 0.000000. mean reward 106.624207.
# World Perf: Episode 1234.000000. Reward 108.000000. action: 0.000000. mean reward 105.811890.
# World Perf: Episode 1237.000000. Reward 124.000000. action: 0.000000. mean reward 106.637115.
# World Perf: Episode 1240.000000. Reward 131.333333. action: 1.000000. mean reward 106.957153.
# World Perf: Episode 1243.000000. Reward 82.000000. action: 0.000000. mean reward 106.043526.
# World Perf: Episode 1246.000000. Reward 122.000000. action: 1.000000. mean reward 107.196449.
# World Perf: Episode 1249.000000. Reward 143.333333. action: 1.000000. mean reward 109.469360.
# World Perf: Episode 1252.000000. Reward 109.000000. action: 1.000000. mean reward 108.597969.
# World Perf: Episode 1255.000000. Reward 70.000000. action: 0.000000. mean reward 107.190125.
# World Perf: Episode 1258.000000. Reward 82.333333. action: 0.000000. mean reward 107.499992.
# World Perf: Episode 1261.000000. Reward 107.000000. action: 0.000000. mean reward 109.444405.
# World Perf: Episode 1264.000000. Reward 123.000000. action: 1.000000. mean reward 108.604057.
# World Perf: Episode 1267.000000. Reward 55.333333. action: 1.000000. mean reward 109.856377.
# World Perf: Episode 1270.000000. Reward 94.000000. action: 1.000000. mean reward 111.347633.
# World Perf: Episode 1273.000000. Reward 108.000000. action: 0.000000. mean reward 111.390442.
# World Perf: Episode 1276.000000. Reward 134.000000. action: 1.000000. mean reward 110.755455.
# World Perf: Episode 1279.000000. Reward 87.333333. action: 0.000000. mean reward 109.596855.
# World Perf: Episode 1282.000000. Reward 68.666667. action: 0.000000. mean reward 111.010986.
# World Perf: Episode 1285.000000. Reward 78.666667. action: 0.000000. mean reward 111.198730.
# World Perf: Episode 1288.000000. Reward 86.333333. action: 0.000000. mean reward 110.151939.
# World Perf: Episode 1291.000000. Reward 59.000000. action: 0.000000. mean reward 110.614449.
# World Perf: Episode 1294.000000. Reward 124.000000. action: 0.000000. mean reward 112.737030.
# World Perf: Episode 1297.000000. Reward 103.000000. action: 0.000000. mean reward 113.850098.
# World Perf: Episode 1300.000000. Reward 123.000000. action: 0.000000. mean reward 115.698273.
# World Perf: Episode 1303.000000. Reward 135.000000. action: 1.000000. mean reward 116.823364.
# World Perf: Episode 1306.000000. Reward 149.000000. action: 0.000000. mean reward 116.267632.
# World Perf: Episode 1309.000000. Reward 73.333333. action: 1.000000. mean reward 115.136330.
# World Perf: Episode 1312.000000. Reward 154.333333. action: 1.000000. mean reward 114.580925.
# World Perf: Episode 1315.000000. Reward 92.000000. action: 0.000000. mean reward 113.304482.
# World Perf: Episode 1318.000000. Reward 94.666667. action: 0.000000. mean reward 112.627716.
# World Perf: Episode 1321.000000. Reward 83.666667. action: 1.000000. mean reward 113.817719.
# World Perf: Episode 1324.000000. Reward 173.666667. action: 1.000000. mean reward 113.427795.
# World Perf: Episode 1327.000000. Reward 143.333333. action: 1.000000. mean reward 115.656036.
# World Perf: Episode 1330.000000. Reward 165.000000. action: 0.000000. mean reward 116.318390.
# World Perf: Episode 1333.000000. Reward 117.333333. action: 1.000000. mean reward 115.275215.
# World Perf: Episode 1336.000000. Reward 200.000000. action: 1.000000. mean reward 115.630524.
# World Perf: Episode 1339.000000. Reward 76.333333. action: 0.000000. mean reward 114.235756.
# World Perf: Episode 1342.000000. Reward 174.000000. action: 0.000000. mean reward 114.404198.
# World Perf: Episode 1345.000000. Reward 85.333333. action: 0.000000. mean reward 113.559937.
# World Perf: Episode 1348.000000. Reward 149.666667. action: 0.000000. mean reward 112.952904.
# World Perf: Episode 1351.000000. Reward 107.333333. action: 0.000000. mean reward 112.152122.
# World Perf: Episode 1354.000000. Reward 138.000000. action: 1.000000. mean reward 111.716339.
# World Perf: Episode 1357.000000. Reward 177.333333. action: 1.000000. mean reward 114.132629.
# World Perf: Episode 1360.000000. Reward 139.666667. action: 0.000000. mean reward 115.092812.
# World Perf: Episode 1363.000000. Reward 166.333333. action: 1.000000. mean reward 114.776581.
# World Perf: Episode 1366.000000. Reward 143.333333. action: 0.000000. mean reward 117.121834.
# World Perf: Episode 1369.000000. Reward 177.000000. action: 1.000000. mean reward 119.685234.
# World Perf: Episode 1372.000000. Reward 140.333333. action: 0.000000. mean reward 121.749664.
# World Perf: Episode 1375.000000. Reward 144.666667. action: 0.000000. mean reward 123.457802.
# World Perf: Episode 1378.000000. Reward 116.333333. action: 0.000000. mean reward 125.113274.
# World Perf: Episode 1381.000000. Reward 158.333333. action: 1.000000. mean reward 127.337532.
# World Perf: Episode 1384.000000. Reward 185.333333. action: 1.000000. mean reward 129.694473.
# World Perf: Episode 1387.000000. Reward 170.666667. action: 0.000000. mean reward 130.314987.
# World Perf: Episode 1390.000000. Reward 200.000000. action: 1.000000. mean reward 132.377258.
# World Perf: Episode 1393.000000. Reward 168.333333. action: 0.000000. mean reward 131.906448.
# World Perf: Episode 1396.000000. Reward 180.000000. action: 1.000000. mean reward 146.540176.
# World Perf: Episode 1399.000000. Reward 173.666667. action: 0.000000. mean reward 148.919327.
# World Perf: Episode 1402.000000. Reward 153.333333. action: 1.000000. mean reward 147.575226.
# World Perf: Episode 1405.000000. Reward 121.000000. action: 0.000000. mean reward 146.303314.
# World Perf: Episode 1408.000000. Reward 181.333333. action: 0.000000. mean reward 145.334961.
# World Perf: Episode 1411.000000. Reward 184.000000. action: 1.000000. mean reward 146.206711.
# World Perf: Episode 1414.000000. Reward 176.666667. action: 0.000000. mean reward 147.959183.
# World Perf: Episode 1417.000000. Reward 167.666667. action: 1.000000. mean reward 150.017014.
# World Perf: Episode 1420.000000. Reward 200.000000. action: 0.000000. mean reward 149.132797.
# World Perf: Episode 1423.000000. Reward 171.666667. action: 1.000000. mean reward 151.208084.
# World Perf: Episode 1426.000000. Reward 200.000000. action: 0.000000. mean reward 152.539719.
# World Perf: Episode 1429.000000. Reward 200.000000. action: 1.000000. mean reward 151.575912.
# World Perf: Episode 1432.000000. Reward 173.000000. action: 0.000000. mean reward 150.337906.
# World Perf: Episode 1435.000000. Reward 185.666667. action: 1.000000. mean reward 149.274582.
# World Perf: Episode 1438.000000. Reward 193.000000. action: 0.000000. mean reward 151.364883.
# World Perf: Episode 1441.000000. Reward 200.000000. action: 1.000000. mean reward 150.468262.
# World Perf: Episode 1444.000000. Reward 159.000000. action: 0.000000. mean reward 151.876343.
# World Perf: Episode 1447.000000. Reward 194.000000. action: 0.000000. mean reward 153.546371.
# World Perf: Episode 1450.000000. Reward 200.000000. action: 1.000000. mean reward 156.870132.
# World Perf: Episode 1453.000000. Reward 200.000000. action: 0.000000. mean reward 158.828171.
# World Perf: Episode 1456.000000. Reward 182.000000. action: 0.000000. mean reward 161.125519.
# World Perf: Episode 1459.000000. Reward 199.666667. action: 0.000000. mean reward 163.775909.
# World Perf: Episode 1462.000000. Reward 168.333333. action: 0.000000. mean reward 165.220901.
# World Perf: Episode 1465.000000. Reward 200.000000. action: 0.000000. mean reward 166.913269.
# World Perf: Episode 1468.000000. Reward 182.000000. action: 1.000000. mean reward 166.152817.
# World Perf: Episode 1471.000000. Reward 188.333333. action: 0.000000. mean reward 166.418320.
# World Perf: Episode 1474.000000. Reward 200.000000. action: 1.000000. mean reward 166.282028.
# World Perf: Episode 1477.000000. Reward 166.000000. action: 0.000000. mean reward 167.710922.
# World Perf: Episode 1480.000000. Reward 200.000000. action: 0.000000. mean reward 169.649979.
# World Perf: Episode 1483.000000. Reward 174.333333. action: 0.000000. mean reward 171.086502.
# World Perf: Episode 1486.000000. Reward 167.000000. action: 0.000000. mean reward 172.387039.
# World Perf: Episode 1489.000000. Reward 200.000000. action: 1.000000. mean reward 173.911087.
# World Perf: Episode 1492.000000. Reward 196.333333. action: 0.000000. mean reward 174.551651.
# World Perf: Episode 1495.000000. Reward 182.333333. action: 0.000000. mean reward 173.637955.
# World Perf: Episode 1498.000000. Reward 184.666667. action: 0.000000. mean reward 172.860107.
# World Perf: Episode 1501.000000. Reward 200.000000. action: 0.000000. mean reward 172.578934.
# World Perf: Episode 1504.000000. Reward 200.000000. action: 0.000000. mean reward 171.857925.
# World Perf: Episode 1507.000000. Reward 200.000000. action: 1.000000. mean reward 173.100403.
# World Perf: Episode 1510.000000. Reward 174.000000. action: 0.000000. mean reward 174.396805.
# World Perf: Episode 1513.000000. Reward 200.000000. action: 1.000000. mean reward 176.170410.
# World Perf: Episode 1516.000000. Reward 192.333333. action: 1.000000. mean reward 176.933517.
# World Perf: Episode 1519.000000. Reward 169.000000. action: 0.000000. mean reward 177.259384.
# World Perf: Episode 1522.000000. Reward 185.000000. action: 0.000000. mean reward 178.502258.
# World Perf: Episode 1525.000000. Reward 200.000000. action: 0.000000. mean reward 177.670273.
# World Perf: Episode 1528.000000. Reward 200.000000. action: 1.000000. mean reward 178.477600.
# World Perf: Episode 1531.000000. Reward 196.333333. action: 0.000000. mean reward 178.869797.
# World Perf: Episode 1534.000000. Reward 187.666667. action: 0.000000. mean reward 179.930557.
# World Perf: Episode 1537.000000. Reward 198.333333. action: 0.000000. mean reward 180.276001.
# World Perf: Episode 1540.000000. Reward 172.666667. action: 0.000000. mean reward 181.298096.
# World Perf: Episode 1543.000000. Reward 177.000000. action: 0.000000. mean reward 182.045731.
# World Perf: Episode 1546.000000. Reward 191.333333. action: 1.000000. mean reward 180.935867.
# World Perf: Episode 1549.000000. Reward 186.666667. action: 0.000000. mean reward 182.201233.
# World Perf: Episode 1552.000000. Reward 184.666667. action: 1.000000. mean reward 183.420959.
# World Perf: Episode 1555.000000. Reward 200.000000. action: 1.000000. mean reward 184.778992.
# World Perf: Episode 1558.000000. Reward 200.000000. action: 0.000000. mean reward 186.088242.
# World Perf: Episode 1561.000000. Reward 173.333333. action: 0.000000. mean reward 187.026047.
# World Perf: Episode 1564.000000. Reward 164.333333. action: 0.000000. mean reward 186.259048.
# World Perf: Episode 1567.000000. Reward 200.000000. action: 1.000000. mean reward 187.475327.
# ...
# World Perf: Episode 2044.000000. Reward 200.000000. action: 1.000000. mean reward 218.585800.
# World Perf: Episode 2047.000000. Reward 187.666667. action: 0.000000. mean reward 216.241013.
# World Perf: Episode 2050.000000. Reward 200.000000. action: 1.000000. mean reward 216.935074.
# World Perf: Episode 2053.000000. Reward 184.000000. action: 0.000000. mean reward 217.375992.
# World Perf: Episode 2056.000000. Reward 200.000000. action: 0.000000. mean reward 218.100052.
# World Perf: Episode 2059.000000. Reward 200.000000. action: 1.000000. mean reward 218.126038.
# World Perf: Episode 2062.000000. Reward 196.000000. action: 1.000000. mean reward 216.352005.
# World Perf: Episode 2065.000000. Reward 200.000000. action: 0.000000. mean reward 214.857712.
# World Perf: Episode 2068.000000. Reward 200.000000. action: 1.000000. mean reward 212.888733.
# World Perf: Episode 2071.000000. Reward 177.000000. action: 0.000000. mean reward 212.569641.
# World Perf: Episode 2074.000000. Reward 190.000000. action: 1.000000. mean reward 213.170822.
# World Perf: Episode 2077.000000. Reward 200.000000. action: 0.000000. mean reward 211.376755.
# World Perf: Episode 2080.000000. Reward 179.000000. action: 0.000000. mean reward 212.137878.
# World Perf: Episode 2083.000000. Reward 200.000000. action: 1.000000. mean reward 212.498001.
# World Perf: Episode 2086.000000. Reward 179.333333. action: 0.000000. mean reward 213.007339.
# World Perf: Episode 2089.000000. Reward 200.000000. action: 0.000000. mean reward 213.784866.
# World Perf: Episode 2092.000000. Reward 199.666667. action: 1.000000. mean reward 214.514938.
# World Perf: Episode 2095.000000. Reward 200.000000. action: 0.000000. mean reward 213.863159.
# World Perf: Episode 2098.000000. Reward 166.666667. action: 0.000000. mean reward 212.773087.
# World Perf: Episode 2101.000000. Reward 193.666667. action: 1.000000. mean reward 212.514359.
# World Perf: Episode 2104.000000. Reward 191.000000. action: 0.000000. mean reward 213.123978.
# World Perf: Episode 2107.000000. Reward 196.333333. action: 0.000000. mean reward 213.809616.
# World Perf: Episode 2110.000000. Reward 200.000000. action: 0.000000. mean reward 214.577988.
# World Perf: Episode 2113.000000. Reward 200.000000. action: 1.000000. mean reward 215.242966.
# World Perf: Episode 2116.000000. Reward 146.666667. action: 0.000000. mean reward 215.406494.
# World Perf: Episode 2119.000000. Reward 179.666667. action: 1.000000. mean reward 215.144958.
# World Perf: Episode 2122.000000. Reward 200.000000. action: 1.000000. mean reward 215.802994.
# World Perf: Episode 2125.000000. Reward 196.333333. action: 1.000000. mean reward 216.442017.
# World Perf: Episode 2128.000000. Reward 163.333333. action: 1.000000. mean reward 214.338150.
# World Perf: Episode 2131.000000. Reward 194.666667. action: 0.000000. mean reward 215.020035.
# World Perf: Episode 2134.000000. Reward 200.000000. action: 0.000000. mean reward 215.719040.
# World Perf: Episode 2137.000000. Reward 192.333333. action: 1.000000. mean reward 215.945816.
# World Perf: Episode 2140.000000. Reward 197.666667. action: 0.000000. mean reward 216.238541.
# World Perf: Episode 2143.000000. Reward 181.333333. action: 1.000000. mean reward 214.347397.
# World Perf: Episode 2146.000000. Reward 188.000000. action: 1.000000. mean reward 213.863388.
# World Perf: Episode 2149.000000. Reward 200.000000. action: 1.000000. mean reward 212.199692.
# World Perf: Episode 2152.000000. Reward 197.666667. action: 0.000000. mean reward 212.075272.
# World Perf: Episode 2155.000000. Reward 199.666667. action: 1.000000. mean reward 212.866562.
# World Perf: Episode 2158.000000. Reward 200.000000. action: 1.000000. mean reward 213.594971.
# World Perf: Episode 2161.000000. Reward 200.000000. action: 1.000000. mean reward 214.310608.
# World Perf: Episode 2164.000000. Reward 200.000000. action: 1.000000. mean reward 215.001831.
# World Perf: Episode 2167.000000. Reward 200.000000. action: 0.000000. mean reward 215.726440.
# World Perf: Episode 2170.000000. Reward 200.000000. action: 0.000000. mean reward 216.488098.
# World Perf: Episode 2173.000000. Reward 200.000000. action: 1.000000. mean reward 217.177719.
# World Perf: Episode 2176.000000. Reward 199.666667. action: 1.000000. mean reward 217.838318.
# World Perf: Episode 2179.000000. Reward 200.000000. action: 0.000000. mean reward 218.527725.
# World Perf: Episode 2182.000000. Reward 200.000000. action: 0.000000. mean reward 219.262192.
# World Perf: Episode 2185.000000. Reward 200.000000. action: 0.000000. mean reward 219.817627.
# World Perf: Episode 2188.000000. Reward 200.000000. action: 0.000000. mean reward 220.362534.
# World Perf: Episode 2191.000000. Reward 200.000000. action: 0.000000. mean reward 220.956650.
# World Perf: Episode 2194.000000. Reward 200.000000. action: 0.000000. mean reward 221.469650.
# World Perf: Episode 2197.000000. Reward 200.000000. action: 0.000000. mean reward 222.048416.
# World Perf: Episode 2200.000000. Reward 200.000000. action: 0.000000. mean reward 222.550919.
# World Perf: Episode 2203.000000. Reward 200.000000. action: 1.000000. mean reward 221.790573.
# World Perf: Episode 2206.000000. Reward 200.000000. action: 1.000000. mean reward 220.382767.
# World Perf: Episode 2209.000000. Reward 200.000000. action: 0.000000. mean reward 220.589722.
# World Perf: Episode 2212.000000. Reward 200.000000. action: 1.000000. mean reward 221.188644.
# World Perf: Episode 2215.000000. Reward 200.000000. action: 1.000000. mean reward 221.779312.
# World Perf: Episode 2218.000000. Reward 200.000000. action: 0.000000. mean reward 222.346420.
# World Perf: Episode 2221.000000. Reward 200.000000. action: 0.000000. mean reward 222.933853.
# World Perf: Episode 2224.000000. Reward 200.000000. action: 0.000000. mean reward 223.561218.
# World Perf: Episode 2227.000000. Reward 200.000000. action: 1.000000. mean reward 222.578842.
# World Perf: Episode 2230.000000. Reward 200.000000. action: 0.000000. mean reward 223.108932.
# World Perf: Episode 2233.000000. Reward 200.000000. action: 0.000000. mean reward 223.675400.
# World Perf: Episode 2236.000000. Reward 200.000000. action: 1.000000. mean reward 224.234695.
# World Perf: Episode 2239.000000. Reward 200.000000. action: 0.000000. mean reward 224.774429.
# World Perf: Episode 2242.000000. Reward 200.000000. action: 1.000000. mean reward 225.402847.
# World Perf: Episode 2245.000000. Reward 200.000000. action: 1.000000. mean reward 226.150635.
# World Perf: Episode 2248.000000. Reward 200.000000. action: 0.000000. mean reward 226.558731.
# World Perf: Episode 2251.000000. Reward 200.000000. action: 1.000000. mean reward 227.648026.
# World Perf: Episode 2254.000000. Reward 200.000000. action: 0.000000. mean reward 228.064804.
# World Perf: Episode 2257.000000. Reward 200.000000. action: 1.000000. mean reward 228.498901.
# World Perf: Episode 2260.000000. Reward 200.000000. action: 0.000000. mean reward 229.540817.
# World Perf: Episode 2263.000000. Reward 200.000000. action: 0.000000. mean reward 229.916183.
# World Perf: Episode 2266.000000. Reward 200.000000. action: 1.000000. mean reward 230.305847.
# World Perf: Episode 2269.000000. Reward 200.000000. action: 0.000000. mean reward 230.892502.
# World Perf: Episode 2272.000000. Reward 200.000000. action: 1.000000. mean reward 231.401123.
# World Perf: Episode 2275.000000. Reward 200.000000. action: 1.000000. mean reward 231.778381.
# World Perf: Episode 2278.000000. Reward 200.000000. action: 0.000000. mean reward 232.257828.
# World Perf: Episode 2281.000000. Reward 200.000000. action: 1.000000. mean reward 230.702271.
# World Perf: Episode 2284.000000. Reward 200.000000. action: 0.000000. mean reward 231.093796.
# World Perf: Episode 2287.000000. Reward 200.000000. action: 0.000000. mean reward 231.497620.
# World Perf: Episode 2290.000000. Reward 200.000000. action: 0.000000. mean reward 232.067703.
# World Perf: Episode 2293.000000. Reward 200.000000. action: 0.000000. mean reward 232.583740.
# World Perf: Episode 2296.000000. Reward 200.000000. action: 1.000000. mean reward 233.027588.
# World Perf: Episode 2299.000000. Reward 200.000000. action: 1.000000. mean reward 233.424881.
# World Perf: Episode 2302.000000. Reward 200.000000. action: 0.000000. mean reward 233.740051.
# World Perf: Episode 2305.000000. Reward 200.000000. action: 1.000000. mean reward 233.366623.
# World Perf: Episode 2308.000000. Reward 194.666667. action: 0.000000. mean reward 233.378922.
# World Perf: Episode 2311.000000. Reward 200.000000. action: 0.000000. mean reward 233.698563.
# World Perf: Episode 2314.000000. Reward 200.000000. action: 1.000000. mean reward 233.174759.
# World Perf: Episode 2317.000000. Reward 200.000000. action: 1.000000. mean reward 233.493912.
# World Perf: Episode 2320.000000. Reward 200.000000. action: 0.000000. mean reward 233.827194.
# World Perf: Episode 2323.000000. Reward 200.000000. action: 0.000000. mean reward 234.134079.
# World Perf: Episode 2326.000000. Reward 200.000000. action: 1.000000. mean reward 234.419510.
# World Perf: Episode 2329.000000. Reward 200.000000. action: 0.000000. mean reward 234.746155.
# World Perf: Episode 2332.000000. Reward 200.000000. action: 0.000000. mean reward 235.055664.
# World Perf: Episode 2335.000000. Reward 200.000000. action: 1.000000. mean reward 235.332275.
# World Perf: Episode 2338.000000. Reward 200.000000. action: 0.000000. mean reward 235.580933.
# World Perf: Episode 2341.000000. Reward 200.000000. action: 0.000000. mean reward 235.873840.
# World Perf: Episode 2344.000000. Reward 200.000000. action: 1.000000. mean reward 236.153915.
# World Perf: Episode 2347.000000. Reward 200.000000. action: 1.000000. mean reward 236.357620.
# World Perf: Episode 2350.000000. Reward 200.000000. action: 1.000000. mean reward 236.160477.
# World Perf: Episode 2353.000000. Reward 200.000000. action: 0.000000. mean reward 236.435593.
# World Perf: Episode 2356.000000. Reward 200.000000. action: 1.000000. mean reward 236.699219.
# World Perf: Episode 2359.000000. Reward 200.000000. action: 1.000000. mean reward 236.943344.
# World Perf: Episode 2362.000000. Reward 200.000000. action: 1.000000. mean reward 237.182373.
# World Perf: Episode 2365.000000. Reward 200.000000. action: 0.000000. mean reward 237.435349.
# World Perf: Episode 2368.000000. Reward 200.000000. action: 0.000000. mean reward 237.676193.
# World Perf: Episode 2371.000000. Reward 200.000000. action: 0.000000. mean reward 237.918381.
# World Perf: Episode 2374.000000. Reward 200.000000. action: 0.000000. mean reward 238.160049.
# World Perf: Episode 2377.000000. Reward 200.000000. action: 1.000000. mean reward 238.404312.
# World Perf: Episode 2380.000000. Reward 200.000000. action: 0.000000. mean reward 238.660263.
# World Perf: Episode 2383.000000. Reward 200.000000. action: 0.000000. mean reward 238.889954.
# World Perf: Episode 2386.000000. Reward 200.000000. action: 1.000000. mean reward 239.087265.
# World Perf: Episode 2389.000000. Reward 200.000000. action: 0.000000. mean reward 237.687485.
# World Perf: Episode 2392.000000. Reward 200.000000. action: 0.000000. mean reward 237.922379.
# World Perf: Episode 2395.000000. Reward 200.000000. action: 1.000000. mean reward 238.139099.
# World Perf: Episode 2398.000000. Reward 200.000000. action: 0.000000. mean reward 238.532547.
# World Perf: Episode 2401.000000. Reward 200.000000. action: 0.000000. mean reward 238.728714.
# World Perf: Episode 2404.000000. Reward 200.000000. action: 1.000000. mean reward 238.928772.
# World Perf: Episode 2407.000000. Reward 200.000000. action: 0.000000. mean reward 239.207077.
# World Perf: Episode 2410.000000. Reward 200.000000. action: 1.000000. mean reward 239.425125.
# World Perf: Episode 2413.000000. Reward 200.000000. action: 1.000000. mean reward 239.623718.
# World Perf: Episode 2416.000000. Reward 200.000000. action: 0.000000. mean reward 239.847046.
# World Perf: Episode 2419.000000. Reward 200.000000. action: 1.000000. mean reward 240.118835.
# World Perf: Episode 2422.000000. Reward 200.000000. action: 0.000000. mean reward 240.508041.
# World Perf: Episode 2425.000000. Reward 200.000000. action: 1.000000. mean reward 240.681412.
# World Perf: Episode 2428.000000. Reward 200.000000. action: 0.000000. mean reward 240.872299.
# World Perf: Episode 2431.000000. Reward 200.000000. action: 1.000000. mean reward 241.088562.
# World Perf: Episode 2434.000000. Reward 200.000000. action: 1.000000. mean reward 241.300461.
# World Perf: Episode 2437.000000. Reward 200.000000. action: 1.000000. mean reward 241.467880.
# World Perf: Episode 2440.000000. Reward 200.000000. action: 1.000000. mean reward 241.766907.
# World Perf: Episode 2443.000000. Reward 200.000000. action: 1.000000. mean reward 242.010941.
# World Perf: Episode 2446.000000. Reward 200.000000. action: 1.000000. mean reward 242.144119.
# World Perf: Episode 2449.000000. Reward 200.000000. action: 0.000000. mean reward 242.307373.
# World Perf: Episode 2452.000000. Reward 200.000000. action: 0.000000. mean reward 242.647095.
# World Perf: Episode 2455.000000. Reward 200.000000. action: 1.000000. mean reward 242.745804.
# World Perf: Episode 2458.000000. Reward 200.000000. action: 1.000000. mean reward 242.593323.
# World Perf: Episode 2461.000000. Reward 200.000000. action: 0.000000. mean reward 242.814026.
# World Perf: Episode 2464.000000. Reward 200.000000. action: 0.000000. mean reward 242.949722.
# World Perf: Episode 2467.000000. Reward 200.000000. action: 0.000000. mean reward 243.076660.
# World Perf: Episode 2470.000000. Reward 200.000000. action: 0.000000. mean reward 243.348877.
# World Perf: Episode 2473.000000. Reward 200.000000. action: 0.000000. mean reward 242.602478.
# World Perf: Episode 2476.000000. Reward 200.000000. action: 1.000000. mean reward 242.794067.
# World Perf: Episode 2479.000000. Reward 200.000000. action: 0.000000. mean reward 243.094864.
# World Perf: Episode 2482.000000. Reward 200.000000. action: 0.000000. mean reward 243.234421.
# World Perf: Episode 2485.000000. Reward 200.000000. action: 0.000000. mean reward 243.377274.
# World Perf: Episode 2488.000000. Reward 200.000000. action: 1.000000. mean reward 243.722839.
# World Perf: Episode 2491.000000. Reward 200.000000. action: 0.000000. mean reward 243.853638.
# World Perf: Episode 2494.000000. Reward 200.000000. action: 0.000000. mean reward 243.961731.
# World Perf: Episode 2497.000000. Reward 200.000000. action: 0.000000. mean reward 244.099670.
# World Perf: Episode 2500.000000. Reward 200.000000. action: 1.000000. mean reward 244.216797.
# World Perf: Episode 2503.000000. Reward 200.000000. action: 1.000000. mean reward 244.334778.
# World Perf: Episode 2506.000000. Reward 200.000000. action: 0.000000. mean reward 244.574753.
# World Perf: Episode 2509.000000. Reward 159.333333. action: 0.000000. mean reward 244.302902.
# World Perf: Episode 2512.000000. Reward 200.000000. action: 1.000000. mean reward 244.443954.
# World Perf: Episode 2515.000000. Reward 200.000000. action: 0.000000. mean reward 244.681152.
# World Perf: Episode 2518.000000. Reward 200.000000. action: 1.000000. mean reward 244.809311.
# World Perf: Episode 2521.000000. Reward 200.000000. action: 0.000000. mean reward 244.949661.
# World Perf: Episode 2524.000000. Reward 200.000000. action: 0.000000. mean reward 245.182571.
# World Perf: Episode 2527.000000. Reward 200.000000. action: 1.000000. mean reward 245.304489.
# World Perf: Episode 2530.000000. Reward 200.000000. action: 1.000000. mean reward 245.417847.
# World Perf: Episode 2533.000000. Reward 200.000000. action: 1.000000. mean reward 245.673157.
# World Perf: Episode 2536.000000. Reward 185.666667. action: 0.000000. mean reward 245.084274.
# World Perf: Episode 2539.000000. Reward 200.000000. action: 1.000000. mean reward 245.180069.
# World Perf: Episode 2542.000000. Reward 200.000000. action: 0.000000. mean reward 244.873962.
# World Perf: Episode 2545.000000. Reward 200.000000. action: 1.000000. mean reward 242.851944.
# World Perf: Episode 2548.000000. Reward 200.000000. action: 1.000000. mean reward 242.962036.
# World Perf: Episode 2551.000000. Reward 200.000000. action: 1.000000. mean reward 243.124451.
# 2551

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
